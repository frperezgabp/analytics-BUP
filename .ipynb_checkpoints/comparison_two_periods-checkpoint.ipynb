# %%
#1ro medio A SJSB 2021 --- id 29
#2do medio A SJSB 2022 --- id 83

# %%
from jsontodf.transform import * 
import requests
import json
import matplotlib.pyplot as plt 
import numpy as np

# %%
url = "http://api.braveup.co/accounts/signin"
payload = json.dumps({
  "email": "back@braveup.cl",
  "password": "123456"
})
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MSwiaWF0IjoxNjU0MjcwOTI1LCJleHAiOjE2NTY4NjI5MjV9.d4XyewUtD6Aib0LtzUGycdYrmBeijF-MyHYnlOSBc5U',
  'Content-Type': 'application/json'
}
response = requests.request("POST", url, headers=headers, data=payload)
#print(response.text)

json.loads(response.text)['idToken']

headers = {}
headers['Authorization'] = 'Bearer '+json.loads(response.text)['idToken']
headers['Content-Type'] = 'application/json'    
counter = 0

# %%
url = "https://sociogram-api.braveup.co/survey-pre-analityc-formats/"+str(29)
payload={}

response = requests.request("GET", url, headers=headers)
query1 = json.loads(response.text)
df1 = transform(query1['content'])
# Out:
# step 1
# before reading dict
# after reading dict
# step 2
# step 3
# step 4
# step 5

# %%
df1.head(50)
# Out:
#     index     id                   name  answerId  surveyId  \
# 0       0  10576     dominique zamorano        33        55
# 1       1  13288        Magdalena leal         99        55
# 2       2  11742      Constanza Briones        95        55
# 3       3  10628  Maria Paz San Martín        114        55
# 4       4  10279      Fernanda Badilla         11        55
# 5       4  10279      Fernanda Badilla         11        55
# 6       5  13211        Magdalena leal         11        55
# 7       5  13211        Magdalena leal         11        55
# 8       5  13211        Magdalena leal         11        55
# 9       5  13211        Magdalena leal         11        55
# 10      5  13211        Magdalena leal         11        55
# 11      5  13211        Magdalena leal         11        55
# 12      5  13211        Magdalena leal         11        55
# 13      5  13211        Magdalena leal         11        55
# 14      5  13211        Magdalena leal         11        55
# 15      5  13211        Magdalena leal         11        55
# 16      6  10656         Luciano arenas        87        55
# 17      7  10386         Fernanda Parra        11        55
# 18      7  10386         Fernanda Parra        11        55
# 19      7  10386         Fernanda Parra        11        55
# 20      8  10575     dominique zamorano        95        55
# 21      9  10705       Antonia Almarza         41        55
# 22     10  16036         Joaquin Astete       118        55
# 23     11  10378      Fernanda Badilla        112        55
# 24     12  13264          Daniel castro       105        55
# 25     13  16129            Josue Parra        93        55
# 26     14  10405          Diego Cancino        33        55
# 27     15  10647              Mia Nuñez        90        55
# 28     16  15802          Agustín Caruz        46        55
# 29     17  10364       Fernanda quezada       122        55
# 30     18  15801          Agustín Caruz        46        55
# 31     19  16027         Joaquin Astete        33        55
# 32     20  10507           Sofía Reyes        101        55
# 33     21  13216            Marco Mena         43        55
# 34     22  12897       Victoria Faundes       108        55
# 35     23  15842           Enzo Alvarez        79        55
# 36     23  15842           Enzo Alvarez        79        55
# 37     23  15842           Enzo Alvarez        79        55
# 38     23  15842           Enzo Alvarez        79        55
# 39     23  15842           Enzo Alvarez        79        55
# 40     24  10349       Fernanda quezada        38        55
# 41     25  10636              Mia Nuñez        47        55
# 42     26  10438         Camilo Fuentes         8        55
# 43     27  10693         Luciano arenas        95        55
# 44     28  10503           Sofía Reyes         97        55
# 45     29  13281      María Elena Caro         48        55
# 46     30  13130          isidora ogden       114        55
# 47     31  10452         Amaya Chanqueo       122        55
# 29                  NaN                 NaN
# 30                  NaN                 NaN
# 31                  NaN                 NaN
# 32                  NaN                 NaN
# 33                  NaN                 NaN
# 34                  NaN                 NaN
# 35                  NaN                 NaN
# 36                  NaN                 NaN
# 37                  NaN                 NaN
# 38                  NaN                 NaN
# 39                  NaN                 NaN
# 40                  NaN                 NaN
# 41                  NaN                 NaN
# 42                  NaN                 NaN
# 43                  NaN                 NaN
# 44                  NaN                 NaN
# 45                  NaN                 NaN
# 46                  NaN                 NaN
# 47                  NaN                 NaN
# 48                  NaN                 NaN
# 49                  NaN                 NaN

# %%
df1_count = df1[df1.question_id==5][['name','answerId']].groupby('name').count().reset_index()
df1_count.head()
# Out:
#                name  answerId
# 0     Agustín Caruz         1
# 1    Amaya Chanqueo         1
# 2  Antonia Almarza          6
# 3      Antonia Soto         5
# 4    Camilo Fuentes         1

# %%
url = "https://sociogram-api.braveup.co/survey-pre-analityc-formats/"+str(83)
payload={}

response = requests.request("GET", url, headers=headers)
query2 = json.loads(response.text)
df2 = transform(query2['content'])
# Out:
# step 1
# before reading dict
# after reading dict
# step 2
# step 3
# step 4
# step 5

# %%
df_test = df2[df2['question_id']==36]

# %%
#df_test['arc'] = (str(df_test['name'])+str(df_test['response_content'].values)).replace('\n','')
df_test['response_content'] = df_test['response_content'].astype(str) 
df_test['arc'] = df_test[['name', 'response_content']].agg('-'.join, axis=1)
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/francisco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_test['arc'] = df_test['arc'].str.lower()
df_test['arc'].replace(' ', '')
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 748           luciano arenas-mia nuñez
# 266    constanza briones-diego cancino
# 267     constanza briones-enzo alvarez
# 752      luciano arenas-joaquin astete
# 751         luciano arenas-josue parra
#                     ...
# 734       luciano arenas-diego cancino
# 173       camilo fuentes-diego cancino
# 735        luciano arenas-antonia soto
# 172       camilo fuentes-martin guzman
# 174      martina zuñiga-amaya chanqueo
# Name: arc, Length: 225, dtype: object

# %%
df2[df2['question_id']==36].head(2)
# Out:
#      index     id               name  answerId  surveyId  \
# 748    433  28357     Luciano arenas       214      1275
# 266    182  28457  Constanza Briones       214      1275
#
#                    created_at                updated_at  question_id  \
# 748  2022-05-12T18:10:23.565Z  2022-05-12T18:10:23.575Z           36
# 266  2022-05-12T18:12:26.511Z  2022-05-12T18:12:26.528Z           36
#
#      enrollmentId response_content  question_id_text_left  question  \
# 748         11100        Mia Nuñez                     38      36.0
# 266         11098    Diego Cancino                     38      36.0
#
#         Answers  question_id_text_right   Nº Tipo de Grafico (Analisis)  \
# 748  Compañeros                      38    2                      Redes
# 266  Compañeros                      38    2                      Redes
#
#     Pregunta Obligatoria                                Questions Text Name
# 748                   No  Marca a todas las personas de tu curso que con...
# 266                   No  Marca a todas las personas de tu curso que con...

# %%
df2_count =  df2[df2.question_id==36][['name','answerId']].groupby('name').count().reset_index()
df2_count['shift_mean'] = df2_count['answerId'] - np.round(df2_count['answerId'].mean())
df_consolidated = df1_count.merge(df2_count, on='name')
df_consolidated.columns = ['name', '2021_friend_arcs', '2022_friend_arcs', 'shift_mean']
df_consolidated['delta'] = df_consolidated['2022_friend_arcs']- df_consolidated['2021_friend_arcs']

# %%
df2_feel1 = df2[df2.question_id==44][['name','Answers']]
df2_feel1.columns = ['name', 'feel1']
df_consolidated = df_consolidated.merge(df2_feel1, on='name')

df2_feel2 = df2[df2.question_id==45][['name','Answers']]
df2_feel2.columns = ['name', 'feel2']
df_consolidated = df_consolidated.merge(df2_feel2, on='name')

# %% [markdown]
# # Vínculos promedio por alumno antes-después

# %%
df_consolidated['2021_friend_arcs'].mean(), df_consolidated['2022_friend_arcs'].mean()
# Out:
# (3.7, 6.6)

# %%
df_consolidated.sort_values('shift_mean').head()
# Out:
#                        name  2021_friend_arcs  2022_friend_arcs  shift_mean  \
# 0             Agustín Caruz                 1                 2        -4.0
# 22        Pía Belén valdes                  1                 3        -3.0
# 1            Amaya Chanqueo                 1                 4        -2.0
# 4   Catalina Miranda Ortega                 1                 4        -2.0
# 25         Victoria Faundes                 1                 4        -2.0
#
#     delta        feel1        feel2
# 0       1  Más o menos         Bien
# 22      2          Mal  Más o menos
# 1       3  Más o menos     Muy bien
# 4       3         Bien         Bien
# 25      3          Mal  Más o menos

# %%
df_consolidated.sort_values('delta').head()
# Out:
#                  name  2021_friend_arcs  2022_friend_arcs  shift_mean  delta  \
# 16  Lizelot Martínez                 15                 5        -1.0    -10
# 5   Constanza Briones                14                 6         0.0     -8
# 14    Francisca Godoy                 7                 5        -1.0     -2
# 2    Antonia Almarza                  6                 5        -1.0     -1
# 6       Daniel castro                 5                 5        -1.0      0
#
#           feel1        feel2
# 16  Más o menos  Más o menos
# 5   Más o menos         Bien
# 14  Más o menos         Bien
# 2   Más o menos  Más o menos
# 6       Muy mal      Muy mal

# %%
df_consolidated[(df_consolidated['feel1'].isin(['Mal', 'Muy mal'])) | (df_consolidated['feel2'].isin(['Mal', 'Muy mal']))]
# Out:
#                          name  2021_friend_arcs  2022_friend_arcs  shift_mean  \
# 6               Daniel castro                 5                 5        -1.0
# 18      Maria Paz San Martín                  2                10         4.0
# 19  Martina paz Jiménez mezas                 7                13         7.0
# 20            Melanie Vargas                  2                 4        -2.0
# 22          Pía Belén valdes                  1                 3        -3.0
# 25           Victoria Faundes                 1                 4        -2.0
# 26         cristobal vallejos                 2                 5        -1.0
#
#     delta        feel1        feel2
# 6       0      Muy mal      Muy mal
# 18      8  Más o menos          Mal
# 19      6          Mal          Mal
# 20      2  Más o menos          Mal
# 22      2          Mal  Más o menos
# 25      3          Mal  Más o menos
# 26      3          Mal          Mal

# %%
df_consolidated[(df_consolidated['feel1'].isin(['Mal', 'Muy mal'])) | (df_consolidated['feel2'].isin(['Mal', 'Muy mal']))].mean()
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 2021_friend_arcs    2.857143
# 2022_friend_arcs    6.285714
# shift_mean          0.285714
# delta               3.428571
# dtype: float64

# %%
import seaborn as sns
ax = sns.boxplot(x="feel2", y="2022_friend_arcs", order=["Muy mal", "Mal", "Mas o menos", "Bien", "Muy bien"], data=df_consolidated, palette="Set3")

# %%
df2[(df2.question_id==44) & (df2.answerId==246)].head()

# %% [markdown]
# • Cambios en las redes % aristas diferentes
#
# • Cambios en los grados de las redes
#
# • Nuevas amistades
#
# • Desvinculaciones
#
# • Cambio en las densidades de las redes
